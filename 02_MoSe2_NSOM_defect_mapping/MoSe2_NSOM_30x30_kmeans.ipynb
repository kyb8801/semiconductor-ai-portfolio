# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import savgol_filter, find_peaks

MAP_X = 60
SPEC_POINTS = 1024
row_start, row_end = 25, 55
col_start, col_end = 15, 45

x_axis = np.loadtxt('1 Export File (X-Axis).txt')
print('데이터 읽는 중...')
spectra = []
with open('1 Export File (Y-Axis).txt', 'r') as f:
    for row in range(row_end):
        for col in range(MAP_X):
            spectrum = []
            for k in range(SPEC_POINTS):
                line = f.readline()
                if not line:
                    break
                spectrum.append(float(line.strip()))
            if len(spectrum) == SPEC_POINTS:
                if row >= row_start and col_start <= col < col_end:
                    spectra.append(spectrum)

spectra = np.array(spectra)
print(f'shape: {spectra.shape}')
print('완료!')

peak_positions = np.zeros((30,30))
peak_intensities = np.zeros((30,30))
fwhm_map = np.zeros((30,30))
for idx in range(900):
    row = idx//30
    col = idx % 30
# Out:
# 데이터 읽는 중...
# shape: (900, 1024)
# 완료!

# %%
def remove_cosmic_ray (s, threshold=5):
    med = np.median(s)
    std = np.std(s)
    mask = s> med + threshold * std
    sc = s.copy()
    for i in np.where(mask)[0]:
        if 0<i<len(sc)-1:
            sc[i] = (sc[i-1] + sc[i+1])/2
            return sc

baseline= np.percentile(spectra, 10, axis=1, keepdims=True)
spectra_sub = spectra - baseline

spectra_2d = spectra_sub.reshape(30,30,1024)
row_means = spectra_2d.mean(axis=(1,2), keepdims=True)
global_mean = spectra_2d.mean()
spectra_norm = spectra_2d * (global_mean /  (row_means + 1e-10))
spectra_norm = spectra_norm.reshape(900,1024)

print(f'정규화 완료!')
print(f'원본 강도 범위: {spectra_sub.min():.1f} ~ {spectra_sub.max():.1f}')
print(f'정규화 후 범위: {spectra_norm.min():.1f} ~ {spectra_norm.max():.1f}')
# Out:
# 정규화 완료!
# 원본 강도 범위: -36.0 ~ 5900.0
# 정규화 후 범위: -45.5 ~ 7414.0

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

peak_positions = np.zeros((30,30))
peak_intensities = np.zeros((30,30))
fwhm_map = np.zeros((30,30))

for idx in range(900):
    row = idx//30
    col = idx % 30
    spec = spectra_norm[idx]
    spec_clean = remove_cosmic_ray(spec)
    spec_smooth = savgol_filter(spec_clean, 15, 3)
    peaks, _ = find_peaks(spec_smooth, height=spec_smooth.max()*0.3, prominence=5)
    if len(peaks) > 0:
        main_peak = peaks[np.argmax(spec_smooth[peaks])]
        peak_positions[row, col] = x_axis[main_peak]
        peak_intensities[row, col] = spec_smooth[main_peak]
        half_max = spec_smooth[main_peak] /2
        left_idx = (np.abs(spec_smooth[:main_peak] - half_max)).argmin()
        right_idx = (np.abs(spec_smooth[main_peak:] - half_max)).argmin()
        fwhm_map[row, col] = abs(x_axis[main_peak+right_dix] - x_axis[left_idx])

print('피크 추출 완료!')

# K-means Clustering
features = np.stack([peak_positions.flatten(), peak_intensities.flatten(), fwhm_map.flatten()],axis=1)

valid_mask = peak_positions.flatten() > 0
features_valid = features[valid_mask]

scaler = StandardScaler()
features_scaled = scaler.fit_transform(features_valid)

kmeans = KMeans(n_clusters=3, random_state=42, n_init=10)
labels = kmeans.fit_predict(featues_scaled)

cluster_map = np.zeros(900)
cluster_map[valid_mask] = laberls +1
cluster_map = cluster_map.reshape(30,30)


print('K-means 완료!')
print(f'클러스터별 픽셀 수:')
for i in range(1, 4):
    print(f'  Cluster {i}: {(cluster_map==i).sum()}개')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [19], in <cell line: 8>()
#      11 spec = spectra_norm[idx]
#      12 spec_clean = remove_cosmic_ray(spec)
# ---> 13 spec_smooth = savgol_filter(spec_clean, 15, 3)
#      14 peaks, _ = find_peaks(spec_smooth, height=spec_smooth.max()*0.3, prominence=5)
#      15 if len(peaks) > 0:
#
# File C:\ProgramData\Anaconda3\lib\site-packages\scipy\signal\_savitzky_golay.py:339, in savgol_filter(x, window_length, polyorder, deriv, delta, axis, mode, cval)
#     337 if mode == "interp":
#     338     if window_length > x.size:
# --> 339         raise ValueError("If mode is 'interp', window_length must be less "
#     340                          "than or equal to the size of x.")
#     342     # Do not pad. Instead, for the elements within `window_length // 2`
#     343     # of the ends of the sequence, use the polynomial that is fitted to
#     344     # the last `window_length` elements.
#     345     y = convolve1d(x, coeffs, axis=axis, mode="constant")
#
# ValueError: If mode is 'interp', window_length must be less than or equal to the size of x.

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# spectra_norm을 2차원으로 변환
spectra_norm_2d = spectra_norm.reshape(900, 1024)

peak_positions = np.zeros((30, 30))
peak_intensities = np.zeros((30, 30))
fwhm_map = np.zeros((30, 30))

for idx in range(900):
    row = idx // 30
    col = idx % 30
    spec = spectra_norm_2d[idx]
    spec_clean = remove_cosmic_ray(spec)
    spec_smooth = savgol_filter(spec_clean, 15, 3)
    peaks, _ = find_peaks(spec_smooth,
                          height=spec_smooth.max()*0.3,
                          prominence=5)
    if len(peaks) > 0:
        main_peak = peaks[np.argmax(spec_smooth[peaks])]
        peak_positions[row, col] = x_axis[main_peak]
        peak_intensities[row, col] = spec_smooth[main_peak]
        half_max = spec_smooth[main_peak] / 2
        left_idx = (np.abs(spec_smooth[:main_peak] - half_max)).argmin()
        right_idx = (np.abs(spec_smooth[main_peak:] - half_max)).argmin()
        fwhm_map[row, col] = abs(x_axis[main_peak+right_idx] - x_axis[left_idx])

print('피크 추출 완료!')
print(f'Peak position: {peak_positions[peak_positions>0].min():.1f} ~ {peak_positions.max():.1f} meV')
print(f'Peak intensity: {peak_intensities[peak_intensities>0].min():.1f} ~ {peak_intensities.max():.1f}')
print(f'FWHM: {fwhm_map[fwhm_map>0].min():.1f} ~ {fwhm_map.max():.1f} meV')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [25], in <cell line: 11>()
#      14 spec = spectra_norm_2d[idx]
#      15 spec_clean = remove_cosmic_ray(spec)
# ---> 16 spec_smooth = savgol_filter(spec_clean, 15, 3)
#      17 peaks, _ = find_peaks(spec_smooth,
#      18                       height=spec_smooth.max()*0.3,
#      19                       prominence=5)
#      20 if len(peaks) > 0:
#
# File C:\ProgramData\Anaconda3\lib\site-packages\scipy\signal\_savitzky_golay.py:339, in savgol_filter(x, window_length, polyorder, deriv, delta, axis, mode, cval)
#     337 if mode == "interp":
#     338     if window_length > x.size:
# --> 339         raise ValueError("If mode is 'interp', window_length must be less "
#     340                          "than or equal to the size of x.")
#     342     # Do not pad. Instead, for the elements within `window_length // 2`
#     343     # of the ends of the sequence, use the polynomial that is fitted to
#     344     # the last `window_length` elements.
#     345     y = convolve1d(x, coeffs, axis=axis, mode="constant")
#
# ValueError: If mode is 'interp', window_length must be less than or equal to the size of x.

# %%
print(f'spectra_norm shape: {spectra_norm.shape}')
print(f'spectra_norm ndim: {spectra_norm.ndim}')
print(f'spectra_norm[0] shape: {spectra_norm[0].shape}')
# Out:
# spectra_norm shape: (900, 1024)
# spectra_norm ndim: 2
# spectra_norm[0] shape: (1024,)

# %%
print(f'spectra_norm shape: {spectra_norm.shape}')
print(f'spectra_norm[0] shape: {spectra_norm[0].shape}')
print(f'spectra_norm[0] 첫 5개 값: {spectra_norm[0][:5]}')

# savgol_filter 직접 테스트
from scipy.signal import savgol_filter
test = savgol_filter(spectra_norm[0], 15, 3)
print(f'savgol_filter 테스트 성공: {test.shape}')
# Out:
# spectra_norm shape: (900, 1024)
# spectra_norm[0] shape: (1024,)
# spectra_norm[0] 첫 5개 값: [5.59112223 8.38668335 0.         8.38668335 6.52297594]
# savgol_filter 테스트 성공: (1024,)

# %%
# remove_cosmic_ray 함수가 정의됐는지 확인
try:
    test = remove_cosmic_ray(spectra_norm[0])
    print(f'함수 정상: {test.shape}')
except NameError:
    print('함수가 정의되지 않음! 다시 정의 필요')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [31], in <cell line: 2>()
#       2 try:
#       3     test = remove_cosmic_ray(spectra_norm[0])
# ----> 4     print(f'함수 정상: {test.shape}')
#       5 except NameError:
#       6     print('함수가 정의되지 않음! 다시 정의 필요')
#
# AttributeError: 'NoneType' object has no attribute 'shape'

# %%
def remove_cosmic_ray(s, threshold=5):
    med = np.median(s)
    std = np.std(s)
    mask = s > med + threshold * std
    sc = s.copy()
    for i in np.where(mask)[0]:
        if 0 < i < len(sc)-1:
            sc[i] = (sc[i-1] + sc[i+1]) / 2
    return sc

# 테스트
test = remove_cosmic_ray(spectra_norm[0])
print(f'함수 정상: {test.shape}')
# Out:
# 함수 정상: (1024,)

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

peak_positions = np.zeros((30, 30))
peak_intensities = np.zeros((30, 30))
fwhm_map = np.zeros((30, 30))

for idx in range(900):
    row = idx // 30
    col = idx % 30
    spec = spectra_norm[idx]
    spec_clean = remove_cosmic_ray(spec)
    spec_smooth = savgol_filter(spec_clean, 15, 3)
    peaks, _ = find_peaks(spec_smooth,
                          height=spec_smooth.max()*0.3,
                          prominence=5)
    if len(peaks) > 0:
        main_peak = peaks[np.argmax(spec_smooth[peaks])]
        peak_positions[row, col] = x_axis[main_peak]
        peak_intensities[row, col] = spec_smooth[main_peak]
        half_max = spec_smooth[main_peak] / 2
        left_idx = (np.abs(spec_smooth[:main_peak] - half_max)).argmin()
        right_idx = (np.abs(spec_smooth[main_peak:] - half_max)).argmin()
        fwhm_map[row, col] = abs(x_axis[main_peak+right_idx] - x_axis[left_idx])

print('피크 추출 완료!')
print(f'Peak position: {peak_positions[peak_positions>0].min():.1f} ~ {peak_positions.max():.1f} meV')
print(f'Peak intensity: {peak_intensities[peak_intensities>0].min():.1f} ~ {peak_intensities.max():.1f}')
print(f'FWHM: {fwhm_map[fwhm_map>0].min():.1f} ~ {fwhm_map.max():.1f} meV')

# K-means Clustering
features = np.stack([
    peak_positions.flatten(),
    peak_intensities.flatten(),
    fwhm_map.flatten()
], axis=1)

valid_mask = peak_positions.flatten() > 0
features_valid = features[valid_mask]

scaler = StandardScaler()
features_scaled = scaler.fit_transform(features_valid)

kmeans = KMeans(n_clusters=3, random_state=42, n_init=10)
labels = kmeans.fit_predict(features_scaled)

cluster_map = np.zeros(900)
cluster_map[valid_mask] = labels + 1
cluster_map = cluster_map.reshape(30, 30)

print('K-means 완료!')
for i in range(1, 4):
    print(f'  Cluster {i}: {(cluster_map==i).sum()}개 픽셀')
# Out:
# 피크 추출 완료!
# Peak position: 676.4 ~ 945.5 meV
# Peak intensity: 63.3 ~ 803.8
# FWHM: 2.2 ~ 198.3 meV
# K-means 완료!
#   Cluster 1: 879개 픽셀
#   Cluster 2: 12개 픽셀
#   Cluster 3: 9개 픽셀

# %%
fig, axes = plt.subplots(2, 2, figsize=(14, 12))

# 1. Peak Intensity Map
im1 = axes[0,0].imshow(peak_intensities, cmap='hot', origin='upper')
axes[0,0].set_title('Peak Intensity Map', fontsize=12)
axes[0,0].set_xlabel('X pixel')
axes[0,0].set_ylabel('Y pixel')
plt.colorbar(im1, ax=axes[0,0], label='Intensity (CCD cts)')

# 2. Peak Position Map
im2 = axes[0,1].imshow(peak_positions, cmap='RdYlBu', origin='upper')
axes[0,1].set_title('Peak Position Map (meV)', fontsize=12)
axes[0,1].set_xlabel('X pixel')
axes[0,1].set_ylabel('Y pixel')
plt.colorbar(im2, ax=axes[0,1], label='Energy (meV)')

# 3. FWHM Map
im3 = axes[1,0].imshow(fwhm_map, cmap='viridis', origin='upper')
axes[1,0].set_title('FWHM Map (meV)', fontsize=12)
axes[1,0].set_xlabel('X pixel')
axes[1,0].set_ylabel('Y pixel')
plt.colorbar(im3, ax=axes[1,0], label='FWHM (meV)')

# 4. K-means Cluster Map
cmap_cluster = plt.cm.get_cmap('Set1', 4)
im4 = axes[1,1].imshow(cluster_map, cmap=cmap_cluster,
                        origin='upper', vmin=0, vmax=3)
axes[1,1].set_title('K-means Cluster Map (k=3)', fontsize=12)
axes[1,1].set_xlabel('X pixel')
axes[1,1].set_ylabel('Y pixel')
cbar = plt.colorbar(im4, ax=axes[1,1], ticks=[0,1,2,3])
cbar.set_ticklabels(['No peak', 'Cluster 1', 'Cluster 2', 'Cluster 3'])

plt.suptitle('MoSe2 NSOM - 30x30 Hyperspectral Analysis + K-means',
             fontsize=14, fontweight='bold')
plt.tight_layout()
plt.savefig('MoSe2_kmeans.png', dpi=150)
plt.show()
print('완료!')
# Out:
# 완료!

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\kyb88
